# %% [markdown]
# <a href="https://colab.research.google.com/github/othrif/DataInsights/blob/master/FirstColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Colab Demo
# Colab is a host of Jupyter Notebooks. Each notebook can run on Google cloud, downloaded to run locally, and/or uploaded to github!
#
# Great way to save your work and share it.

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()
